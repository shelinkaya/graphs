# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([29.48, 37.8,10.88,21.84])

mylabels = ["  Muzaffer Nasıroğlu","  Engin Nasıroğlu","  Ömer Faruk Nasıroğlu","  Hasan Ekmen\n  Nihat Terece\n  M. Sabih Ataç\n  Osman İlten\n  M.Can Ortaboy"]
mycolors = [ "red", "orange", "blue","green"]
myexplode = [ 0, 0, 0,0.2]

plt.pie(y, labels = mylabels, colors = mycolors,explode = myexplode, shadow = True)

#my.eplode.move(())
plt.legend(bbox_to_anchor=(1.8, 0.5), loc='center right', borderaxespad=0)
#plt.legend(loc='center right')
#image.save()
plt.show()
